# %%
import pandas as pd
from datetime import datetime

# %%
# Variaveis
current_date = datetime.now().date()
file_path = f"../datalake/vagasdotcom/{current_date}/vagas_extraidas.csv"

# Lendo o arquivo CSV e carregando em um DataFrame
df = pd.read_csv(file_path)

# %%
display(df)
# Out:
#                 cargo      nome_empresa                             salario  \
# 0       Técnico em TI           Veolink           Faixa salarial a combinar
# 1       Técnico de TI           Veolink           Faixa salarial a combinar
# 2    Assistente de TI       Oceaneering           Faixa salarial a combinar
# 3    Supervisor de TI  Penso Tecnologia  Faixa salarial R$ 6.000 a R$ 7.000
# 4       Gerente de TI      Confidencial           Faixa salarial a combinar
# ..                ...               ...                                 ...
# 435               NaN               NaN                                 NaN
# 436               NaN               NaN                                 NaN
# 437               NaN               NaN                                 NaN
# 438               NaN               NaN                                 NaN
# 439               NaN               NaN                                 NaN
#
#               local regime_trabalista  \
# ...
